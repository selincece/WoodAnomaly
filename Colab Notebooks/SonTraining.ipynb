# %% [markdown]
# ### **GLASS**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Neural_Networks_Project/GLASS
# Out:
# /content/drive/MyDrive/Neural_Networks_Project/GLASS

# %%
#  Gerekli kütüphanelerin yüklenmesi
# !pip install -r requirements.txt #cuda_pythonu 11.8.2 den 11.8.3 e gecirdim
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 100.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 105.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 105.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.8/200.8 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 95.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Neural_Networks_Project/GLASS/shell
# !chmod +x run-wood.sh
# Out:
# /content/drive/MyDrive/Neural_Networks_Project/GLASS/shell

# %%
# !./run-wood.sh
# Out:
# 2025-05-14 12:36:09.218113: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-14 12:36:09.236089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747226169.257786    3451 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747226169.264353    3451 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ### EfficientAd

# %%
# %cd /content/drive/MyDrive/Neural_Networks_Project/EfficientAD
# Out:
# /content/drive/MyDrive/Neural_Networks_Project/EfficientAD

# %%
# !python efficientad.py --dataset mvtec_ad --subdataset wood --train_steps 40000
# Out:
# Computing mean of features: 100% 63/63 [00:01<00:00, 31.66it/s]
# Computing std of features: 100% 63/63 [00:01<00:00, 31.74it/s]
# Current loss: 4.8120  :  25% 10000/40000 [05:11<11:54, 41.99it/s]
# Intermediate map normalization:   0% 0/7 [00:00<?, ?it/s]
# Intermediate map normalization:  14% 1/7 [00:00<00:00,  9.67it/s]
# Intermediate map normalization:  43% 3/7 [00:00<00:00, 11.29it/s]
# Intermediate map normalization:  71% 5/7 [00:00<00:00, 11.83it/s]
# Intermediate map normalization: 100% 7/7 [00:00<00:00, 11.54it/s]
#
# Intermediate inference:   0% 0/141 [00:00<?, ?it/s]
# Intermediate inference:   2% 3/141 [00:00<00:04, 28.47it/s]
# Intermediate inference:   4% 6/141 [00:00<00:04, 28.66it/s]
# Intermediate inference:   6% 9/141 [00:00<00:04, 27.46it/s]
# Intermediate inference:   9% 12/141 [00:00<00:04, 26.89it/s]
# Intermediate inference:  11% 15/141 [00:00<00:04, 27.69it/s]
# Intermediate inference:  13% 18/141 [00:00<00:04, 28.15it/s]
# ...

# %% [markdown]
# ### INP FORMER

# %%
# %cd /content/drive/MyDrive/Neural_Networks_Project/INP-Former
# Out:
# /content/drive/MyDrive/Neural_Networks_Project/INP-Former

# %%
# !pip install kornia==0.7.3
# !pip install adeval==1.1.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.3/833.3 kB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 101.6 MB/s eta 0:00:00
# ...

# %%
# !python INP_Former_Single_Class.py --dataset MVTec-AD --data_path /content/drive/MyDrive/Neural_Networks_Project/wood_dataset --phase train
# Out:
# train image number:70
# 100%|█████████████████████████████████████████████| 4/4 [00:04<00:00,  1.05s/it]
# epoch [1/400], loss:1.1023
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.26it/s]
# epoch [2/400], loss:0.6632
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.24it/s]
# epoch [3/400], loss:0.5593
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.27it/s]
# epoch [4/400], loss:0.4999
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.27it/s]
# epoch [5/400], loss:0.4460
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.29it/s]
# epoch [6/400], loss:0.3998
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.23it/s]
# epoch [7/400], loss:0.3861
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.28it/s]
# epoch [8/400], loss:0.3635
# ...
